# %%
import requests
import json

# %%
base_url = "https://itunes.apple.com/search"

# %%
url = base_url + "?tearm=the+beatles&country=us"
requests.get(url)
# Out:
# <Response [200]>

# %%
r = requests.get(base_url, params={"terms": "the beatles", "country": "us"})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?terms=the+beatles&country=us'

# %% [markdown]
# Investigating the output and parameters

# %%
info = r.json()
print(json.dumps(info, indent=4))
# Out:
# {
#     "resultCount": 0,
#     "results": []
# }

# %% [markdown]
# Pagination}

# %%
base_site = "https://jobs.github.com/positions.json"

# %%
r = requests.get(base_site, params={"description": "data science", "location": "berlin"})
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': 'fbb9e6fe-4f4b-4a6c-9c49-fb9584a058cb',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/fbb9e6fe-4f4b-4a6c-9c49-fb9584a058cb',
#   'created_at': 'Mon Aug 31 11:44:14 UTC 2020',
#   'company': 'Digital Charging Solutions GmbH',
#   'company_url': 'https://digitalchargingsolutions.com/web/dcs-global',
#   'location': 'Berlin',
#   'title': 'Fullstack Java Developer (m/f/d)',
# ...

# %%
len(r.json())
# Out:
# 1

# %%
r = requests.get(base_site)
r.ok
# Out:
# True

# %%
r.json()
# Out:
# [{'id': 'c219fa2f-0aff-40fa-a3b0-d2b4674ec0fa',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/c219fa2f-0aff-40fa-a3b0-d2b4674ec0fa',
#   'created_at': 'Tue Sep 08 12:30:34 UTC 2020',
#   'company': 'CompuGroup Medical',
#   'company_url': 'https://vonq.io/2EVh60o',
#   'location': 'Echt',
#   'title': '(Lead) Software Architect',
# ...

# %%
len(r.json())
# Out:
# 50

# %%
r = requests.get(base_site, params={'page':2})
r.json()
# Out:
# [{'id': 'e09d8cc5-8767-40f9-9b3b-be027c5f1481',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/e09d8cc5-8767-40f9-9b3b-be027c5f1481',
#   'created_at': 'Thu Aug 27 12:43:16 UTC 2020',
#   'company': 'Phantasma Labs',
#   'company_url': 'https://phantasma.global/',
#   'location': 'Berlin',
#   'title': 'Software Engineer - Unreal Engine',
# ...

# %%
r = requests.get(base_site, params={"page":3})
len(r.json())
# Out:
# 14

# %%
r = requests.get(base_site, params={"page":10})
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# []

# %% [markdown]
# Extract Result from Multiple Pages

# %%
results = []

# %%
for i in range(5):
    r = requests.get(base_site, params={"page": i+1})
    if len(r.json()) == 0:
        break
    else:
        results.extend(r.json())

# %%
len(results)
# Out:
# 114
